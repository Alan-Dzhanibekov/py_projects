# %%
import matplotlib
import pandas
import seaborn
import psycopg2

conn = psycopg2.connect(dbname = "amocrmleads" , user = "dzhal89", password = "!@iKwRMKOw!64^2#Y7" , host = "data.sharpsir.group", port="55432")
print("Подключение установлено")
# Out:
# Подключение установлено
